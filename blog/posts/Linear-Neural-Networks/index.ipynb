# %% [raw]
# ---
# title: Teste Notebook
# date: "2026-06-30"
# categories: [python]
# description: Teste de notebook + vscode + github pages quarto
# ---

# %% [markdown]
# # Teste simples
#
# Notebook de teste gerado para verificar o ambiente.

# %%
import numpy as np

a = 3
b = 5
print(f"a + b = {a + b}")

x = np.array([1, 2, 3, 4, 5])
print("x:", x)
print("media:", x.mean())
# Out:
# a + b = 8
# x: [1 2 3 4 5]
# media: 3.0

# %%
def quadrado(n):
    return n ** 2

for i in range(1, 6):
    print(f"{i}^2 = {quadrado(i)}")
# Out:
# 1^2 = 1
# 2^2 = 4
# 3^2 = 9
# 4^2 = 16
# 5^2 = 25

# %% [markdown]
# ## Gráfico 3D com Plotly

# %%
import plotly.io as pio
pio.renderers.default = "notebook_connected"
import numpy as np
import plotly.graph_objects as go

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x ** 2 + y ** 2))

fig = go.Figure(data=[go.Surface(x=x, y=y, z=z, colorscale="Viridis")])
fig.update_layout(
    title="Superfície 3D: z = sin(sqrt(x² + y²))",
    scene=dict(xaxis_title="x", yaxis_title="y", zaxis_title="z"),
    width=800,
    height=600,
)
fig.show()
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.6.0.min"</script>
# <div style="height:600px; width:800px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
